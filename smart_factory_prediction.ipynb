# %%
from matplotlib import font_manager, rc
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import platform
import random
import os

if platform.system() == 'Windows':
    # 윈도우인 경우 맑은 고딕 폰트 이용
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf"
                                           ).get_name()
    rc('font', family=font_name)
else:    
# Mac 인 경우
    rc('font', family='AppleGothic')

#그래프에서 마이너스 기호가 표시되게 하는 설정입니다.
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
train_df = pd.read_csv('/Users/hyunjoon/Desktop/LG AIMER/hackerton/open/train.csv')
print(train_df.shape)
display(train_df.head(-1))
# Out:
# (598, 2881)
#     PRODUCT_ID  Y_Class  Y_Quality         TIMESTAMP     LINE PRODUCT_CODE  \
# 0    TRAIN_000        1   0.533433   2022-06-13 5:14  T050304         A_31
# 1    TRAIN_001        2   0.541819   2022-06-13 5:22  T050307         A_31
# 2    TRAIN_002        1   0.531267   2022-06-13 5:30  T050304         A_31
# 3    TRAIN_003        2   0.537325   2022-06-13 5:39  T050307         A_31
# 4    TRAIN_004        1   0.531590   2022-06-13 5:47  T050304         A_31
# ..         ...      ...        ...               ...      ...          ...
# 592  TRAIN_592        1   0.528349  2022-09-08 14:22  T100304         T_31
# 593  TRAIN_593        1   0.526546  2022-09-08 14:30  T100306         T_31
# 594  TRAIN_594        0   0.524022  2022-09-08 22:38  T050304         A_31
# 595  TRAIN_595        0   0.521289  2022-09-08 22:47  T050304         A_31
# 596  TRAIN_596        1   0.531375  2022-09-08 14:38  T100304         O_31
#
# ...

# %%
display(train_df.describe())
# Out:
#           Y_Class   Y_Quality         X_1         X_2    X_3    X_4  \
# count  598.000000  598.000000  349.000000  349.000000  349.0  349.0
# mean     1.025084    0.530896    2.409742   95.123209    0.0   45.0
# std      0.565069    0.007401    5.895256    4.107640    0.0    0.0
# min      0.000000    0.500856    1.000000   87.000000    0.0   45.0
# 25%      1.000000    0.527535    2.000000   93.000000    0.0   45.0
# 50%      1.000000    0.530436    2.000000   95.000000    0.0   45.0
# 75%      1.000000    0.533433    2.000000   98.000000    0.0   45.0
# max      2.000000    0.578841  103.000000  102.000000    0.0   45.0
#
#               X_5    X_6         X_7         X_8  ...      X_2866     X_2867  \
# count  349.000000  349.0  349.000000  349.000000  ...  100.000000  100.00000
# mean    10.392550    0.0   48.802292   10.048711  ...   50.807300   53.60770
# std      0.489019    0.0    4.373824    0.215571  ...    7.011828    8.13899
# ...

# %%
# names = []
# for i in range(1,2876):
#     tmp = 'X_' + str(i)
#     names.append(tmp)
# cnt = 0
# for i in names:
#     if train_df[i].count() <100:
#         print(i, ' count : ',train_df[i].count())
#         train_df = train_df.drop(columns=i)
#         cnt +=1
#     else:
#         pass
# Out:
# X_128  count :  78
# X_129  count :  78
# X_130  count :  42
# X_131  count :  42
# X_337  count :  59
# X_338  count :  59
# X_339  count :  59
# X_340  count :  70
# X_341  count :  70
# X_342  count :  70
# X_356  count :  70
# X_357  count :  70
# X_358  count :  70
# X_360  count :  59
# X_361  count :  59
# X_362  count :  59
# X_371  count :  59
# X_372  count :  59
# X_373  count :  70
# X_374  count :  70
# X_382  count :  78
# X_383  count :  42
# X_529  count :  87
# X_530  count :  87
# X_531  count :  87
# X_532  count :  87
# X_533  count :  87
# X_561  count :  10
# X_600  count :  87
# X_601  count :  87
# X_602  count :  87
# X_603  count :  87
# X_604  count :  87
# X_699  count :  10
# X_759  count :  10
# X_760  count :  10
# X_761  count :  10
# X_934  count :  0
# X_935  count :  0
# X_936  count :  0
# X_937  count :  0
# X_1167  count :  94
# X_1168  count :  94
# X_1169  count :  94
# X_1170  count :  94
# X_1171  count :  94
# X_1219  count :  6
# ...

# %%
# Out:
# 632

# %%
product_codes = train_df['PRODUCT_CODE'].unique()

# %%
print(product_codes)
product_A = pd.DataFrame()
product_T = pd.DataFrame()
product_O = pd.DataFrame()
# Out:
# ['A_31' 'T_31' 'O_31']

# %%
for i, r in train_df.iterrows():
    print('Now Processing Index : ', i, end=' ')
    if r['PRODUCT_CODE'] == product_codes[0]:
        print(r['PRODUCT_CODE'])
        product_A = product_A.append(r, ignore_index=True)
    elif r['PRODUCT_CODE'] == product_codes[1]:
        print(r['PRODUCT_CODE'])
        product_T = product_T.append(r, ignore_index=True)
    elif r['PRODUCT_CODE'] == product_codes[2]:
        print(r['PRODUCT_CODE'])
        product_O = product_O.append(r, ignore_index=True)
    else:
        pass
# Out:
# Now Processing Index :  0 A_31
# Now Processing Index :  1 A_31
# Now Processing Index :  2 A_31
# Now Processing Index :  3 A_31
# Now Processing Index :  4 A_31
# Now Processing Index :  5 A_31
# Now Processing Index :  6 A_31
# Now Processing Index :  7 A_31
# Now Processing Index :  8 A_31
# Now Processing Index :  9 A_31
# Now Processing Index :  10 A_31
# Now Processing Index :  11 A_31
# Now Processing Index :  12 A_31
# Now Processing Index :  13 A_31
# Now Processing Index :  14 A_31
# Now Processing Index :  15 A_31
# Now Processing Index :  16 A_31
# Now Processing Index :  17 A_31
# Now Processing Index :  18 A_31
# Now Processing Index :  19 A_31
# Now Processing Index :  20 A_31
# Now Processing Index :  21 A_31
# Now Processing Index :  22 T_31
# Now Processing Index :  23 T_31
# Now Processing Index :  24 A_31
# Now Processing Index :  25 T_31
# Now Processing Index :  26 T_31
# Now Processing Index :  27 A_31
# Now Processing Index :  28 A_31
# ...

# %%
product_A.head(20)
# Out:
#    PRODUCT_ID  Y_Class  Y_Quality        TIMESTAMP     LINE PRODUCT_CODE  X_1  \
# 0   TRAIN_000      1.0   0.533433  2022-06-13 5:14  T050304         A_31  NaN
# 1   TRAIN_001      2.0   0.541819  2022-06-13 5:22  T050307         A_31  NaN
# 2   TRAIN_002      1.0   0.531267  2022-06-13 5:30  T050304         A_31  NaN
# 3   TRAIN_003      2.0   0.537325  2022-06-13 5:39  T050307         A_31  NaN
# 4   TRAIN_004      1.0   0.531590  2022-06-13 5:47  T050304         A_31  NaN
# 5   TRAIN_005      2.0   0.537833  2022-06-13 5:55  T050307         A_31  NaN
# 6   TRAIN_006      1.0   0.533665  2022-06-13 6:03  T050304         A_31  NaN
# 7   TRAIN_007      2.0   0.540003  2022-06-13 6:11  T050307         A_31  NaN
# 8   TRAIN_008      1.0   0.531821  2022-06-13 6:19  T050304         A_31  NaN
# 9   TRAIN_009      2.0   0.538049  2022-06-13 6:28  T050307         A_31  NaN
# 10  TRAIN_010      1.0   0.531503  2022-06-13 6:36  T050304         A_31  NaN
# ...

# %%
product_T.head(20)
# Out:
#    PRODUCT_ID  Y_Class  Y_Quality         TIMESTAMP     LINE PRODUCT_CODE  \
# 0   TRAIN_022      0.0   0.517719   2022-06-14 8:53  T100304         T_31
# 1   TRAIN_023      0.0   0.519090   2022-06-14 9:01  T100304         T_31
# 2   TRAIN_025      1.0   0.529362   2022-06-19 9:11  T100304         T_31
# 3   TRAIN_026      1.0   0.531992   2022-06-19 9:20  T100306         T_31
# 4   TRAIN_029      1.0   0.532405  2022-06-19 23:31  T100304         T_31
# 5   TRAIN_030      1.0   0.528646  2022-06-19 23:39  T100306         T_31
# 6   TRAIN_036      1.0   0.529633   2022-06-22 3:39  T100306         T_31
# 7   TRAIN_037      1.0   0.533110   2022-06-22 3:47  T100304         T_31
# 8   TRAIN_042      1.0   0.530965   2022-06-23 3:39  T100306         T_31
# 9   TRAIN_043      1.0   0.529498   2022-06-23 6:28  T100306         T_31
# 10  TRAIN_044      1.0   0.530489   2022-06-23 6:36  T100306         T_31
# 11  TRAIN_045      1.0   0.530948  2022-06-23 10:24  T100304         T_31
# ...

# %%
product_O
# Out:
#   PRODUCT_ID  Y_Class  Y_Quality         TIMESTAMP     LINE PRODUCT_CODE  \
# 0  TRAIN_569      1.0   0.530533  2022-09-03 18:32  T100304         O_31
# 1  TRAIN_570      2.0   0.534951  2022-09-03 18:40  T100306         O_31
# 2  TRAIN_571      1.0   0.525916  2022-09-03 18:48  T100304         O_31
# 3  TRAIN_572      2.0   0.535205  2022-09-03 18:56  T100306         O_31
# 4  TRAIN_596      1.0   0.531375  2022-09-08 14:38  T100304         O_31
# 5  TRAIN_597      1.0   0.533702  2022-09-08 14:46  T100306         O_31
#
#     X_1    X_2  X_3   X_4  ...  X_2866  X_2867  X_2868  X_2869  X_2870  \
# 0   4.0   98.0  0.0  45.0  ...     NaN     NaN     NaN     NaN     NaN
# 1   6.0   90.0  0.0  45.0  ...     NaN     NaN     NaN     NaN     NaN
# 2   4.0  100.0  0.0  45.0  ...     NaN     NaN     NaN     NaN     NaN
# 3   6.0   89.0  0.0  45.0  ...     NaN     NaN     NaN     NaN     NaN
# 4  40.0   94.0  0.0  45.0  ...     NaN     NaN     NaN     NaN     NaN
# ...

# %%
print(product_A.shape)
print(product_T.shape)
print(product_O.shape)
# Out:
# (249, 2881)
# (343, 2881)
# (6, 2881)

# %%
product_A = product_A.dropna(axis = 1)
product_T = product_T.dropna(axis = 1)
product_O = product_O.dropna(axis = 1)

# %%
print(product_A.shape)
print(product_T.shape)
print(product_O.shape)
# Out:
# (249, 248)
# (343, 236)
# (6, 656)

# %%
product_A.head()
# Out:
#   PRODUCT_ID  Y_Class  Y_Quality        TIMESTAMP     LINE PRODUCT_CODE  \
# 0  TRAIN_000      1.0   0.533433  2022-06-13 5:14  T050304         A_31
# 1  TRAIN_001      2.0   0.541819  2022-06-13 5:22  T050307         A_31
# 2  TRAIN_002      1.0   0.531267  2022-06-13 5:30  T050304         A_31
# 3  TRAIN_003      2.0   0.537325  2022-06-13 5:39  T050307         A_31
# 4  TRAIN_004      1.0   0.531590  2022-06-13 5:47  T050304         A_31
#
#    X_284  X_955  X_956    X_1002  ...  X_2856  X_2857      X_2858  X_2859  \
# 0    1.0   51.0  -26.0 -5.740741  ...   181.6   139.6  131.646667   115.4
# 1    1.0   62.0  -26.0  3.471698  ...   177.1   145.5  128.748276   119.7
# 2    1.0   69.0  -34.0  7.320755  ...   183.6   128.0  115.365517   104.0
# 3    1.0   68.0  -22.0  7.075472  ...   179.5   126.2  112.082759    94.5
# 4    1.0   59.0  -22.0  8.981481  ...   188.0   152.1  138.066667   109.7
#
#    X_2860      X_2861  X_2862  X_2863      X_2864  X_2865
# ...

# %%
product_T.head()
# Out:
#   PRODUCT_ID  Y_Class  Y_Quality         TIMESTAMP     LINE PRODUCT_CODE  X_1  \
# 0  TRAIN_022      0.0   0.517719   2022-06-14 8:53  T100304         T_31  2.0
# 1  TRAIN_023      0.0   0.519090   2022-06-14 9:01  T100304         T_31  2.0
# 2  TRAIN_025      1.0   0.529362   2022-06-19 9:11  T100304         T_31  2.0
# 3  TRAIN_026      1.0   0.531992   2022-06-19 9:20  T100306         T_31  2.0
# 4  TRAIN_029      1.0   0.532405  2022-06-19 23:31  T100304         T_31  2.0
#
#      X_2  X_3   X_4  ...  X_884  X_885  X_886  X_887  X_888  X_889  X_898  \
# 0  102.0  0.0  45.0  ...    7.5    0.3    0.0    0.0    0.0    0.0   10.0
# 1  102.0  0.0  45.0  ...    7.4    0.4    0.0    0.0    0.0    0.0   10.0
# 2   97.0  0.0  45.0  ...    7.4    0.5    0.0    0.0    0.0    0.0   13.0
# 3   95.0  0.0  45.0  ...    7.6    0.3    0.0    0.0    0.0    0.0   12.0
# 4  100.0  0.0  45.0  ...    7.4    0.5    0.0    0.0    0.0    0.0   13.0
#
#       X_899  X_900  X_901
# ...

# %%
product_O.head()
# Out:
#   PRODUCT_ID  Y_Class  Y_Quality         TIMESTAMP     LINE PRODUCT_CODE  \
# 0  TRAIN_569      1.0   0.530533  2022-09-03 18:32  T100304         O_31
# 1  TRAIN_570      2.0   0.534951  2022-09-03 18:40  T100306         O_31
# 2  TRAIN_571      1.0   0.525916  2022-09-03 18:48  T100304         O_31
# 3  TRAIN_572      2.0   0.535205  2022-09-03 18:56  T100306         O_31
# 4  TRAIN_596      1.0   0.531375  2022-09-08 14:38  T100304         O_31
#
#     X_1    X_2  X_3   X_4  ...  X_924  X_925       X_926  X_927  X_928  \
# 0   4.0   98.0  0.0  45.0  ...  181.7  160.0  155.541935  149.8  327.0
# 1   6.0   90.0  0.0  45.0  ...  176.0  161.9  157.464516  154.5  327.0
# 2   4.0  100.0  0.0  45.0  ...  175.4  165.7  159.864516  148.7  326.0
# 3   6.0   89.0  0.0  45.0  ...  166.1  166.0  161.046667  151.3  326.0
# 4  40.0   94.0  0.0  45.0  ...  189.2  179.5  173.190323  168.6  321.0
#
#         X_929  X_930  X_931      X_932  X_933
# 0  312.018182  298.0   13.6  13.458065   13.3
# ...

# %%
""" 
1. product별로 dataFrame을 따로 분류

print(product_A.shape)
print(product_T.shape)
print(product_O.shape)
----------------------
(249, 2881)
(343, 2881)
(6, 2881)

2. 각 product 별로 결측값인 컬럼 제거
product_A = product_A.dropna(axis = 1)
product_T = product_T.dropna(axis = 1)
product_O = product_O.dropna(axis = 1)

print(product_A.shape)
print(product_T.shape)
print(product_O.shape)
----------------------------------------
(249, 248)
(343, 236)
(6, 656)

내 뇌피셜:
단순 계산만 해봐도 (248 + 236 + 656) == 1140 
이 결과로 봤을때 유니크로 거르는 거보다 실제로 쓰이는 컬럼만 모아서 학습시키면 좋은 결과가 나올것 같다.

"""

# %%
col_A = product_A.columns
col_T = product_T.columns
col_O = product_O.columns

col_sum = []

# %%
for i in col_A:
    # print(i)
    if i not in col_sum:
        col_sum.append(i)

for i in col_T:
    # print(i)
    if i not in col_sum:
        col_sum.append(i)
        
for i in col_O:
    # print(i)
    if i not in col_sum:
        col_sum.append(i)

# %%
col_sum_idx = pd.Index(col_sum)

# %%
print(col_sum_idx)
# Out:
# Index(['PRODUCT_ID', 'Y_Class', 'Y_Quality', 'TIMESTAMP', 'LINE',
#        'PRODUCT_CODE', 'X_284', 'X_955', 'X_956', 'X_1002',
#        ...
#        'X_924', 'X_925', 'X_926', 'X_927', 'X_928', 'X_929', 'X_930', 'X_931',
#        'X_932', 'X_933'],
#       dtype='object', length=898)

# %%
org_idx = train_df.columns
for i in org_idx:
    print('Now Processing Index : ', i)
    if i not in col_sum:
        train_df = train_df.drop(columns=i)
# Out:
# Now Processing Index :  PRODUCT_ID
# Now Processing Index :  Y_Class
# Now Processing Index :  Y_Quality
# Now Processing Index :  TIMESTAMP
# Now Processing Index :  LINE
# Now Processing Index :  PRODUCT_CODE
# Now Processing Index :  X_1
# Now Processing Index :  X_2
# Now Processing Index :  X_3
# Now Processing Index :  X_4
# Now Processing Index :  X_5
# Now Processing Index :  X_6
# Now Processing Index :  X_7
# Now Processing Index :  X_8
# Now Processing Index :  X_9
# Now Processing Index :  X_10
# Now Processing Index :  X_11
# Now Processing Index :  X_12
# Now Processing Index :  X_13
# Now Processing Index :  X_14
# Now Processing Index :  X_15
# Now Processing Index :  X_16
# Now Processing Index :  X_17
# Now Processing Index :  X_18
# Now Processing Index :  X_19
# Now Processing Index :  X_20
# Now Processing Index :  X_21
# Now Processing Index :  X_22
# Now Processing Index :  X_23
# Now Processing Index :  X_24
# Now Processing Index :  X_25
# ...

# %%
test_df = pd.read_csv('/Users/hyunjoon/Desktop/LG AIMER/hackerton/open/test.csv')
org_idx = test_df.columns
for i in org_idx:
    print('Now Processing Index : ', i)
    if i not in col_sum:
        test_df = test_df.drop(columns=i)
# Out:
# Now Processing Index :  PRODUCT_ID
# Now Processing Index :  TIMESTAMP
# Now Processing Index :  LINE
# Now Processing Index :  PRODUCT_CODE
# Now Processing Index :  X_1
# Now Processing Index :  X_2
# Now Processing Index :  X_3
# Now Processing Index :  X_4
# Now Processing Index :  X_5
# Now Processing Index :  X_6
# Now Processing Index :  X_7
# Now Processing Index :  X_8
# Now Processing Index :  X_9
# Now Processing Index :  X_10
# Now Processing Index :  X_11
# Now Processing Index :  X_12
# Now Processing Index :  X_13
# Now Processing Index :  X_14
# Now Processing Index :  X_15
# Now Processing Index :  X_16
# Now Processing Index :  X_17
# Now Processing Index :  X_18
# Now Processing Index :  X_19
# Now Processing Index :  X_20
# Now Processing Index :  X_21
# Now Processing Index :  X_22
# Now Processing Index :  X_23
# Now Processing Index :  X_24
# Now Processing Index :  X_25
# Now Processing Index :  X_26
# Now Processing Index :  X_27
# ...

# %%
train_df = train_df.drop(columns= ['PRODUCT_ID','TIMESTAMP'])
print(train_df.shape)
# Out:
# (598, 896)

# %%
train_df = train_df.drop(columns=['Y_Quality'])
train_df.head()
# Out:
#    Y_Class     LINE PRODUCT_CODE  X_1  X_2  X_3  X_4  X_5  X_6  X_7  ...  \
# 0        1  T050304         A_31  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 1        2  T050307         A_31  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 2        1  T050304         A_31  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 3        2  T050307         A_31  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 4        1  T050304         A_31  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
#
#    X_2856  X_2857      X_2858  X_2859  X_2860      X_2861  X_2862  X_2863  \
# 0   181.6   139.6  131.646667   115.4   209.0  197.286667   189.0   383.0
# 1   177.1   145.5  128.748276   119.7   198.0  193.296552   185.6   383.0
# 2   183.6   128.0  115.365517   104.0   193.4  179.820690   165.5   383.0
# 3   179.5   126.2  112.082759    94.5   190.3  181.920690   165.8   384.0
# 4   188.0   152.1  138.066667   109.7   208.6  196.393333   182.6   383.0
#
#        X_2864  X_2865
# 0  368.296296   353.0
# 1  367.735849   353.0
# ...

# %%
train_x = train_df.drop(columns=['Y_Class'])
train_y = train_df['Y_Class']

# %%
test_df = test_df.drop(columns=['PRODUCT_ID',"TIMESTAMP"])
test_df.head()
# Out:
#       LINE PRODUCT_CODE  X_1   X_2  X_3   X_4   X_5  X_6   X_7   X_8  ...  \
# 0  T100306         T_31  2.0  94.0  0.0  45.0  10.0  0.0  51.0  10.0  ...
# 1  T100304         T_31  2.0  93.0  0.0  45.0  11.0  0.0  45.0  10.0  ...
# 2  T100304         T_31  2.0  95.0  0.0  45.0  11.0  0.0  45.0  10.0  ...
# 3  T010305         A_31  NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN  ...
# 4  T010306         A_31  NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN  ...
#
#    X_2856  X_2857      X_2858  X_2859  X_2860      X_2861  X_2862  X_2863  \
# 0     NaN     NaN         NaN     NaN     NaN         NaN     NaN     NaN
# 1     NaN     NaN         NaN     NaN     NaN         NaN     NaN     NaN
# 2     NaN     NaN         NaN     NaN     NaN         NaN     NaN     NaN
# 3   159.4   201.3  179.739286   149.9   198.0  191.450000   183.8   467.0
# 4   175.3   227.9  190.664286   162.4   210.2  193.082143   179.7   465.0
#
#        X_2864  X_2865
# 0         NaN     NaN
# 1         NaN     NaN
# ...

# %%
test_x = test_df

# %%
display(train_x.head())
display(test_x.head())
display(train_y.head())
# Out:
#       LINE PRODUCT_CODE  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  ...  X_2856  \
# 0  T050304         A_31  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...   181.6
# 1  T050307         A_31  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...   177.1
# 2  T050304         A_31  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...   183.6
# 3  T050307         A_31  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...   179.5
# 4  T050304         A_31  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...   188.0
#
#    X_2857      X_2858  X_2859  X_2860      X_2861  X_2862  X_2863      X_2864  \
# 0   139.6  131.646667   115.4   209.0  197.286667   189.0   383.0  368.296296
# 1   145.5  128.748276   119.7   198.0  193.296552   185.6   383.0  367.735849
# 2   128.0  115.365517   104.0   193.4  179.820690   165.5   383.0  367.320755
# 3   126.2  112.082759    94.5   190.3  181.920690   165.8   384.0  369.188679
# 4   152.1  138.066667   109.7   208.6  196.393333   182.6   383.0  367.351852
#
#    X_2865
# 0   353.0
# 1   353.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import GradientBoostingClassifier
import xgboost as xgb

# %%
SEED = 37
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)


seed_everything(SEED)

# %%
# qualitative to quantitative
qual_col = ['LINE', 'PRODUCT_CODE']

for i in qual_col:
    le = LabelEncoder()
    le = le.fit(train_x[i])
    train_x[i] = le.transform(train_x[i])
    
    # for label in np.unique(x_test[i]): 
    #     if label not in le.classes_: 
    #         le.classes_ = np.append(le.classes_, label)
    # x_test[i] = le.transform(x_test[i])
    for label in np.unique(test_x[i]): 
        if label not in le.classes_: 
            le.classes_ = np.append(le.classes_, label)
    test_x[i] = le.transform(test_x[i])  
print('Done.')
# Out:
# Done.

# %%
XGB = xgb.XGBClassifier()
XGB.fit(train_x,train_y)
# Out:
# /Users/hyunjoon/opt/anaconda3/envs/MLDL/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [18:46:16] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
# ...

# %%
pred = XGB.predict(test_x)

# %%
submit = pd.read_csv('/Users/hyunjoon/Desktop/LG AIMER/hackerton/open/sample_submission.csv')

# %%
submit['Y_Class'] = pred

# %%
submit_reset = submit.set_index('PRODUCT_ID')

# %%
submit_reset.head()
# Out:
#             Y_Class
# PRODUCT_ID
# TEST_000          1
# TEST_001          1
# TEST_002          1
# TEST_003          1
# TEST_004          1

# %%
submit_reset.to_csv('/Users/hyunjoon/Desktop/LG AIMER/hackerton/submissions/XGB_submission.csv')

# %%
x_train_fill_0 = train_x.fillna(0)
x_test_fill_0 = test_x.fillna(0)

# %%
RF = GradientBoostingClassifier(random_state=37).fit(x_train_fill_0, train_y)
print('Done.')
# Out:
# Done.

# %%
preds = RF.predict(x_test_fill_0)
print('Done.')
# Out:
# Done.

# %%
submit = pd.read_csv('/Users/hyunjoon/Desktop/LG AIMER/hackerton/open/sample_submission.csv')

# %%
submit['Y_Class'] = preds

# %%
submit_reset = submit.set_index('PRODUCT_ID')

# %%
submit_reset.head(10)
# Out:
#             Y_Class
# PRODUCT_ID
# TEST_000          1
# TEST_001          2
# TEST_002          1
# TEST_003          1
# TEST_004          1
# TEST_005          1
# TEST_006          1
# TEST_007          2
# TEST_008          0
# TEST_009          1

# %%
submit_reset.to_csv('/Users/hyunjoon/Desktop/LG AIMER/hackerton/submissions/GB_submission.csv')
